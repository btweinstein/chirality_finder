# %% [markdown]
# I am going to apply Melanie's idea here and use a Pratt Circle fit followed by a "Orthogonal Residues" fit. Let's see what works here. I am going to take the code from
#
# http://wiki.scipy.org/Cookbook/Least_Squares_Circle#head-f353234ac19e695689375c7eaa2df9ab64938a03
#
# as a starting point.

# %%
# %reset
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])? y

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import chirality_data_analysis as chd
from chirality_data_analysis import example_data as ex
import pandas as pd

# %%
imageData = ex.imageData
largestDates = imageData.sort('date').groupby(['T','mL']).last()
largestDates = largestDates.reset_index()
display(largestDates.head(3))
# Out:
#     T  mL                                               path        name  \
# 0  21  25  /home/bryan/Documents/Research_Data/Nelson/Chi...  ReplicateB
# 1  21  50  /home/bryan/Documents/Research_Data/Nelson/Chi...  ReplicateA
# 2  21  56  /home/bryan/Documents/Research_Data/Nelson/Chi...  ReplicateB
#
#                  date
# 0 2013-10-29 00:00:00
# 1 2013-10-29 00:00:00
# 2 2013-10-21 00:00:00

# %%
import skimage.io
import skimage as ski

# %%
img = ski.io.imread(largestDates['path'].iloc[0])
fluor1 = img[:, :, 0]
fluor2 = img[:, :, 1]
brightfield = img[:, :, 2]
ski.io.imshow(img)

# %% [markdown]
# This seems like a reasonable example to test. Let's prepare the binary.

# %%
ski.io.imshow(brightfield)

# %% [markdown]
# Let's find the edges in this.

# %%
import skimage.filter

# %%
binary = ski.filter.canny(brightfield, sigma=5)
ski.io.imshow(binary)

# %% [markdown]
# This looks pretty reasonable. Let's use this as our test. A sigma of 5 here seems to get rid of the features we don't care about.

# %%
y, x = np.nonzero(binary)
print x
print y
# Out:
# [651 656 657 ..., 656 657 683]
# [111 111 111 ..., 908 908 908]

# %%
plt.plot(x, y, '+')
plt.axis('equal')
# Out:
# (200.0, 1100.0, 100.0, 1000.0)

# %% [markdown]
# This should be a pretty easy example to work from. Let's test what happens.

# %%
from numpy import *

basename = 'circle'

# %% [markdown]
# # Algebraic Circle Fit

# %%
def algebraic_circleFind(x, y):
    # == METHOD 1: Algebraic ==

    # coordinates of the barycenter
    x_m = mean(x)
    y_m = mean(y)
    
    # calculation of the reduced coordinates
    u = x - x_m
    v = y - y_m
    
    # linear system defining the center in reduced coordinates (uc, vc):
    #    Suu * uc +  Suv * vc = (Suuu + Suvv)/2
    #    Suv * uc +  Svv * vc = (Suuv + Svvv)/2
    Suv  = sum(u*v)
    Suu  = sum(u**2)
    Svv  = sum(v**2)
    Suuv = sum(u**2 * v)
    Suvv = sum(u * v**2)
    Suuu = sum(u**3)
    Svvv = sum(v**3)
    
    # Solving the linear system
    A = array([ [ Suu, Suv ], [Suv, Svv]])
    B = array([ Suuu + Suvv, Svvv + Suuv ])/2.0
    uc, vc = linalg.solve(A, B)
    
    xc = x_m + uc
    yc = y_m + vc
    
    # Calculation of all distances from the center (xc_1, yc_1)
    Ri      = sqrt((x-xc)**2 + (y-yc)**2)
    R       = mean(Ri)
    residu  = sum((Ri- R)**2)
    residu2 = sum((Ri **2-R**2)**2)
    
    return (xc, yc), (R, Ri), (residu, residu2)

# %%
algebraic_circleFind(x, y)
# Out:
# ((661.28263638038788, 510.03919623145356),
#  (396.1894257732302,
#   array([ 399.17165824,  399.0741615 ,  399.06217699, ...,  397.99586378,
#         397.9838468 ,  398.55293904])),
#  (16662.382991021674, 10495532130.654564))

# %% [markdown]
# # Least Squares

# %%
from scipy import optimize

def leastSq_circleFind(x, y):
    
    def calc_R(xc, yc):
        """ calculate the distance of each 2D points from the center (xc, yc) """
        return sqrt((x-xc)**2 + (y-yc)**2)
    
    def f_2(c):
        """ calculate the algebraic distance between the 2D points and the mean circle centered at c=(xc, yc) """
        Ri = calc_R(*c)
        return Ri - Ri.mean()
    
    center_estimate = mean(x), mean(y)
    center, ier = optimize.leastsq(f_2, center_estimate)
    
    xc, yc = center
    Ri       = calc_R(xc, yc)
    R        = Ri.mean()
    residu   = sum((Ri - R)**2)
    residu2  = sum((Ri**2-R**2)**2)
    
    return (xc, yc), (R, Ri), (residu, residu2)

# %%
leastSq_circleFind(x, y)
# Out:
# ((661.28008130459182, 510.05282454665087),
#  (396.18885750688736,
#   array([ 399.18521622,  399.08775481,  399.07577711, ...,  397.98220276,
#         397.97019178,  398.53947022])),
#  (16662.088939405268, 10495717961.760553))

# %%
from scipy import optimize

def leastSq_circleFind_jacobian(x, y):
    # == METHOD 2b ==
    # Advanced usage, with jacobian
    
    def calc_R(xc, yc):
        """ calculate the distance of each 2D points from the center c=(xc, yc) """
        return sqrt((x-xc)**2 + (y-yc)**2)
    
    def f_2b(c):
        """ calculate the algebraic distance between the 2D points and the mean circle centered at c=(xc, yc) """
        Ri = calc_R(*c)
        return Ri - Ri.mean()
    
    
    def Df_2b(c):
        """ Jacobian of f_2b
        The axis corresponding to derivatives must be coherent with the col_deriv option of leastsq"""
        xc, yc     = c
        df2b_dc    = empty((len(c), x.size))
    
        Ri = calc_R(xc, yc)
        df2b_dc[ 0] = (xc - x)/Ri                   # dR/dxc
        df2b_dc[ 1] = (yc - y)/Ri                   # dR/dyc
        df2b_dc       = df2b_dc - df2b_dc.mean(axis=1)[:, newaxis]
    
        return df2b_dc
    
    center_estimate = mean(x), mean(y)
    center_2b, ier = optimize.leastsq(f_2b, center_estimate, Dfun=Df_2b, col_deriv=True)
    
    xc_2b, yc_2b = center_2b
    Ri_2b        = calc_R(xc_2b, yc_2b)
    R_2b         = Ri_2b.mean()
    residu_2b    = sum((Ri_2b - R_2b)**2)
    residu2_2b   = sum((Ri_2b**2-R_2b**2)**2)
    
    return (xc_2b, yc_2b), (R_2b, Ri_2b), (residu_2b, residu2_2b)

# %%
leastSq_circleFind_jacobian(x ,y)
# Out:
# ((661.28008131208219, 510.05282454018982),
#  (396.18885750691453,
#   array([ 399.18521622,  399.0877548 ,  399.0757771 , ...,  397.98220276,
#         397.97019179,  398.53947022])),
#  (16662.088939405272, 10495717961.555227))

# %% [markdown]
# # ODR: Implicit Function Definition

# %%
# == METHOD 3 ==

from scipy import  odr

def odr_circleFind(x, y):
    # Basic usage of odr with an implicit function definition
    def f_3(beta, x):
        """ implicit definition of the circle """
        return (x[0]-beta[0])**2 + (x[1]-beta[1])**2 -beta[2]**2
    
    def calc_R(xc, yc):
        """ calculate the distance of each 2D points from the center c=(xc, yc) """
        return sqrt((x-xc)**2 + (y-yc)**2)
    
    # initial guess for parameters
    x_m, y_m = mean(x), mean(y)
    R_m = calc_R(x_m, y_m).mean()
    beta0 = [ x_m, y_m, R_m]
    
    
    # for implicit function :
    #       data.x contains both coordinates of the points
    #       data.y is the dimensionality of the response
    lsc_data   = odr.Data(row_stack([x, y]), y=1)
    lsc_model  = odr.Model(f_3, implicit=True)
    lsc_odr    = odr.ODR(lsc_data, lsc_model, beta0)
    lsc_out    = lsc_odr.run()
    
    xc_3, yc_3, R_3 = lsc_out.beta
    Ri_3       = calc_R(xc_3, yc_3)
    residu_3   = sum((Ri_3 - R_3)**2)
    residu2_3  = sum((Ri_3**2-R_3**2)**2)
    
    return (xc_3, yc_3), (R_3, Ri_3), (residu_3, residu2_3)

# %%
odr_circleFind(x, y)
# Out:
# ((661.28008157902104, 510.05282465623992),
#  (396.18885749206851,
#   array([ 399.18521634,  399.08775492,  399.07577722, ...,  397.98220265,
#         397.97019168,  398.53947009])),
#  (16662.088939405105, 10495717963.350658))

# %%
def odr_circleFind_jacobian(x, y):
    # Advanced usage, with jacobian
    
    x_m = mean(x)
    y_m = mean(y)

    def f_3b(beta, x):
        """ implicit definition of the circle """
        return (x[0]-beta[0])**2 + (x[1]-beta[1])**2 -beta[2]**2
    
    def calc_R(xc, yc):
        """ calculate the distance of each 2D points from the center c=(xc, yc) """
        return sqrt((x-xc)**2 + (y-yc)**2)

    def jacb(beta, x):
        """ Jacobian function with respect to the parameters beta.
        return df_3b/dbeta
        """
        xc, yc, r = beta
        xi, yi    = x
    
        df_db    = empty((beta.size, x.shape[1]))
        df_db[0] =  2*(xc-xi)                     # d_f/dxc
        df_db[1] =  2*(yc-yi)                     # d_f/dyc
        df_db[2] = -2*r                           # d_f/dr
    
        return df_db

    def jacd(beta, x):
        """ Jacobian function with respect to the input x.
        return df_3b/dx
        """
        xc, yc, r = beta
        xi, yi    = x
    
        df_dx    = empty_like(x)
        df_dx[0] =  2*(xi-xc)                     # d_f/dxi
        df_dx[1] =  2*(yi-yc)                     # d_f/dyi
    
        return df_dx


    def calc_estimate(data):
        """ Return a first estimation on the parameter from the data  """
        xc0, yc0 = data.x.mean(axis=1)
        r0 = sqrt((data.x[0]-xc0)**2 +(data.x[1] -yc0)**2).mean()
        return xc0, yc0, r0

    # for implicit function :
    #       data.x contains both coordinates of the points
    #       data.y is the dimensionality of the response
    lsc_data  = odr.Data(row_stack([x, y]), y=1)
    lsc_model = odr.Model(f_3b, implicit=True, estimate=calc_estimate, fjacd=jacd, fjacb=jacb)
    lsc_odr   = odr.ODR(lsc_data, lsc_model)    # beta0 has been replaced by an estimate function
    lsc_odr.set_job(deriv=3)                    # use user derivatives function without checking
    lsc_odr.set_iprint(iter=1, iter_step=1)     # print details for each iteration
    lsc_out   = lsc_odr.run()
    
    xc_3b, yc_3b, R_3b = lsc_out.beta
    Ri_3b       = calc_R(xc_3b, yc_3b)
    residu_3b   = sum((Ri_3b - R_3b)**2)
    residu2_3b  = sum((Ri_3b**2-R_3b**2)**2)
    
    return (xc_3b, yc_3b), (R_3b, Ri_3b), (residu_3b, residu2_3b)

# %%
odr_circleFind_jacobian(x, y)
# Out:
# ((661.2800815767049, 510.05282465768158),
#  (396.18885749071438,
#   array([ 399.18521634,  399.08775492,  399.07577722, ...,  397.98220265,
#         397.97019167,  398.53947009])),
#  (16662.088939405101, 10495717963.435713))

# %% [markdown]
# # Conclusion

# %% [markdown]
# Let us now put this into PyCharm and compare our results.
